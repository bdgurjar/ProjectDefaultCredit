# %%
import pandas as pd

# %%
#data ingestion form excel sheet
df=pd.read_excel("./data/default of credit card clients.xls",header=1)

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4
# 0   1      20000    2          2         1   24      2      2     -1     -1  \
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3
# 0  ...          0          0          0         0       689         0  \
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0                           1
# 1      1000         0      2000                           1
# 2      1000      1000      5000                           0
# 3      1100      1069      1000                           0
# 4      9000       689       679                           0
#
# [5 rows x 25 columns]

# %%
#checking null values
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#checking correlation 
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
##dropping corelated columns
df=df.drop(labels=["PAY_3","PAY_5","PAY_6","BILL_AMT2","BILL_AMT3","BILL_AMT4","BILL_AMT5","BILL_AMT6"],axis=1)

# %%
#changing name of columns from space value to continuous value
df["default_payment_next_month"]=df["default payment next month"]

# %%
#dropping copy columns
df=df.drop(labels=["default payment next month"],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_4                       30000 non-null  int64
#  9   BILL_AMT1                   30000 non-null  int64
#  10  PAY_AMT1                    30000 non-null  int64
#  11  PAY_AMT2                    30000 non-null  int64
#  12  PAY_AMT3                    30000 non-null  int64
#  13  PAY_AMT4                    30000 non-null  int64
#  14  PAY_AMT5                    30000 non-null  int64
#  15  PAY_AMT6                    30000 non-null  int64
#  16  default_payment_next_month  30000 non-null  int64
# dtypes: int64(17)
# memory usage: 3.9 MB

# %%
#### segregate numerical and categorical columns
numerical_cols=["LIMIT_BAL","AGE","BILL_AMT1","PAY_AMT1","PAY_AMT2","PAY_AMT3","PAY_AMT4","PAY_AMT5","PAY_AMT6"]
categor_cols=["SEX","EDUCATION","MARRIAGE","PAY_0","PAY_2","PAY_4"]

# %%
#converting integer column to object
df["SEX"]=df["SEX"].astype("str")
df["EDUCATION"]=df["EDUCATION"].astype("str")
df["MARRIAGE"]=df["MARRIAGE"].astype("str")
df["PAY_0"]=df["PAY_0"].astype("str")
df["PAY_2"]=df["PAY_2"].astype("str")
df["PAY_4"]=df["PAY_4"].astype("str")

# %%
##saving the data as csv file
df.to_csv("data/default of credit card clients data.csv")
